# %% [markdown]
# <a href="https://colab.research.google.com/github/Rub-T/challenge_TelecomX/blob/main/Challenge_TelecomX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %% [markdown]
# ##Importación de paqueterias

# %%
import pandas as pd
import matplotlib as plt
import requests
import numpy as np

# %% [markdown]
# ##Extracción de los datos .json

# %%
url='https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'
request=requests.get(url)
df=request.json()
datos=pd.json_normalize(df)

# %%
datos.sample(10)
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 1245  1777-JYQPJ    No            Male                       0
# 7072  9739-JLPQJ    No          Female                       0
# 5031  6877-TJMBR   Yes            Male                       0
# 5368  7328-OWMOM    No          Female                       0
# 6947  9571-EDEBV    No            Male                       0
# 2034  2868-MZAGQ   Yes            Male                       0
# 6361  8746-BFOAJ    No            Male                       1
# 3350  4657-FWVFY    No          Female                       0
# 1787  2538-OIMXF    No          Female                       0
# 6521  8966-KZXXA    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 1245               No                  No                2                 No
# 7072              Yes                 Yes               72                Yes
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
datos.isnull().sum()
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ##Transformando datos numericos

# %% [markdown]
# **Aqui vamos a empezar con la columna account.Charges.Total que es la unica columna con datos numericos que necesita tranformase, la vamos a cambiar a tipo float y comprobaremos que no nos quede ningun valor nulo**

# %%
datos['account.Charges.Total']=pd.to_numeric(datos['account.Charges.Total'],errors='coerce')
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
datos.isnull().sum()
# Out:
# customerID                    0
# Churn                         0
# customer.gender               0
# customer.SeniorCitizen        0
# customer.Partner              0
# customer.Dependents           0
# customer.tenure               0
# phone.PhoneService            0
# phone.MultipleLines           0
# internet.InternetService      0
# internet.OnlineSecurity       0
# internet.OnlineBackup         0
# internet.DeviceProtection     0
# internet.TechSupport          0
# internet.StreamingTV          0
# internet.StreamingMovies      0
# account.Contract              0
# account.PaperlessBilling      0
# account.PaymentMethod         0
# account.Charges.Monthly       0
# account.Charges.Total        11
# dtype: int64

# %% [markdown]
# Convertimos los datos nulos a 0

# %%
datos['account.Charges.Total']=datos['account.Charges.Total'].fillna(0)
datos['account.Charges.Total'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##Transformando datos booleanos

# %% [markdown]
# Evaluaremos las columnas que parecen tener valores de si y no para comprobar que no tengan otro tipo de dato, evaluaremos las columnas:
#
# Churn,
# customer.Partner,
# customer.Dependents,
# phone.PhoneService,
# phone.MultipleLines,
# internet.OnlineBackup,
# internet.DeviceProtection,
# internet.TechSupport,
# internet.StreamingTV,
# internet.StreamingMovies,
# account.PaperlessBilling

# %%
col_check=['Churn','customer.Partner','customer.Dependents','phone.PhoneService','phone.MultipleLines','internet.OnlineBackup',
'internet.DeviceProtection','internet.TechSupport','internet.StreamingTV','internet.StreamingMovies','account.PaperlessBilling']

for col in col_check:
  print(f'Columna {col}: {datos[col].unique()}')
# Out:
# Columna Churn: [ True False]
# Columna customer.Partner: ['Yes' 'No']
# Columna customer.Dependents: ['Yes' 'No']
# Columna phone.PhoneService: ['Yes' 'No']
# Columna phone.MultipleLines: ['No' 'Yes' 'No phone service']
# Columna internet.OnlineBackup: ['Yes' 'No' 'No internet service']
# Columna internet.DeviceProtection: ['No' 'Yes' 'No internet service']
# Columna internet.TechSupport: ['Yes' 'No' 'No internet service']
# Columna internet.StreamingTV: ['Yes' 'No' 'No internet service']
# Columna internet.StreamingMovies: ['No' 'Yes' 'No internet service']
# Columna account.PaperlessBilling: ['Yes' 'No']

# %% [markdown]
# Ahora que sabemos cuales son los que tienen solo valores de Si y NO los haremos booleanos, los que tengan otro dato lo haremos categorico.

# %%
colum_bool=['Churn','customer.Partner','customer.Dependents','phone.PhoneService','account.PaperlessBilling']
datos[colum_bool]=datos[colum_bool].astype(np.bool_)
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   bool
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   bool
#  5   customer.Dependents        7267 non-null   bool
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   bool
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
datos.sample(5)
# Out:
#       customerID  Churn customer.gender  customer.SeniorCitizen  \
# 807   1140-UKVZG   True          Female                       0
# 3067  4280-DLSHD   True            Male                       0
# 5979  8173-RXAYP   True          Female                       0
# 2354  3280-NMUVX   True            Male                       0
# 6777  9355-NPPFS   True          Female                       1
#
#       customer.Partner  customer.Dependents  customer.tenure  \
# 807               True                 True               17
# 3067              True                 True                8
# 5979              True                 True               24
# 2354              True                 True               34
# 6777              True                 True               26
#
#       phone.PhoneService phone.MultipleLines internet.InternetService  ...  \
# 807                 True                 Yes                       No  ...
# ...

# %%
datos['internet.OnlineSecurity'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %% [markdown]
# ##Transformando datos string

# %% [markdown]
# Ahora solo queda transformar los datos que serán texto

# %%
#Crear lista para filtrar datos
colum_str=['customer.gender','phone.MultipleLines','internet.InternetService','internet.OnlineSecurity','internet.OnlineBackup','internet.DeviceProtection','internet.TechSupport','internet.StreamingTV',
'internet.StreamingMovies','account.Contract','account.PaymentMethod']

#Manipulamos los datos para que sean minisculas
for i in colum_str:
  datos[i]=datos[i].str.lower()
datos.sample(10)
# Out:
#       customerID  Churn customer.gender  customer.SeniorCitizen  \
# 1071  1501-SGHBW   True            male                       0
# 4055  5550-VFRLC   True          female                       1
# 3030  4208-UFFGW   True            male                       1
# 1629  2316-ESMLS   True          female                       0
# 4866  6653-CBBOM   True          female                       0
# 1475  2115-BFTIW   True            male                       0
# 1579  2249-YPRNG   True          female                       0
# 2825  3915-ODIYG   True            male                       1
# 6398  8782-LKFPK   True            male                       0
# 1615  2293-IJWPS   True          female                       0
#
#       customer.Partner  customer.Dependents  customer.tenure  \
# 1071              True                 True                2
# 4055              True                 True                1
# 3030              True                 True                2
# ...

# %% [markdown]
# Asi queda nuestra manipulacion de datos

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   bool
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   bool
#  5   customer.Dependents        7267 non-null   bool
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   bool
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
datos.isnull().sum()
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %% [markdown]
# ##Acomodando nombres de columnas

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final
